# %%
pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Downloading sentencepiece-0.2.0-cp312-cp312-macosx_11_0_arm64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 17.1 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.2.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration
from torch.utils.data import DataLoader, Dataset
from torch.optim import AdamW

# %% [markdown]
# ## Model Loading

# %%
# Step 1: Load the T5 Model and Tokenizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = "t5-small" 
tokenizer = T5Tokenizer.from_pretrained(model, legacy=False)
model = T5ForConditionalGeneration.from_pretrained(model).to(device)

# %% [markdown]
# # Loading the data

# %%
# Step 2: Load the Dataset from CSV
csv_file = "Cleaned_Lang8.csv" 
data = pd.read_csv(csv_file)

# %%
data = data.rename(columns = {'0': "input", '1': "target"})
data
# Out:
#                                                     input  \
# 0       the president was standing in the front row an...
# 1       in us, i heard that arrested people will not l...
# 2       i always practice pronounce, but getting more ...
# 3       if i said that sentence, people will be heard ...
# 4                                 i just learnt alphabet.
# ...                                                   ...
# 199995  she does not want to, but her father did not f...
# 199996  anyway, we feel grief, but on the other hand, ...
# 199997    other countries also lose your grandfather did?
# 199998     it is my first time to be here, i mean lang-8.
# 199999   what can i do what should i do what need i do.!!
#
#                                                    target
# 0       the president was standing in the front row an...
# 1       in the us, i heard that people arrested will n...
# 2       i always practise pronunciation, but it is get...
# 3       if i said that sentence, people would hear the...
# 4                        i have just learnt the alphabet.
# ...                                                   ...
# 199995  she did not want to, but her father did not bu...
# 199996  anyway, we feel grief, but on the other hand, ...
# 199997    did other countries also lose your grandfather?
# 199998        it is my first time here. i mean at lang-8.
# 199999   what can i do what should i do what do i need.!!
#
# [200000 rows x 2 columns]

# %%
data = data.iloc[:1000, :]

# %%
if "input" not in data.columns or "target" not in data.columns:
    raise ValueError("The CSV file must contain 'input' and 'target' columns.")

# %%
# Step 3: Preprocess the Data
input_texts = ["grammar correction: " + text for text in data["input"].tolist()]
target_texts = data["target"].tolist()

# %%
input_texts
# Out:
# ['grammar correction: the president was standing in the front row and the every female enployees were surrounding him.',
#  'grammar correction: in us, i heard that arrested people will not lose their jobs.',
#  'grammar correction: i always practice pronounce, but getting more difficult.',
#  'grammar correction: if i said that sentence, people will be heard same pronounciation.',
#  'grammar correction: i just learnt alphabet.',
#  "grammar correction: i'm always not patient enough to take a self - study for a long time.",
#  'grammar correction: but it is also said that it is very difficult to learn well both of them.',
#  'grammar correction: then i asked my brother for an advice, he said that “ i like japanese.',
#  "grammar correction: i was acquainted with him in a chinese's room chat when i was at 9th grade about 4 years ago.",
#  'grammar correction: he is very humorious and handsome > _ <.',
#  'grammar correction: that is the reason why i did not choose english department despite i like it best.',
#  "grammar correction: this time we still have to test 4 japanese's skill.",
#  "grammar correction: i'm very nervous of speaking and listening skill.",
#  "grammar correction: i'll have to write anything in japanese as topic's request.",
#  "grammar correction: ( my computer's cd room was broken so that i cannot install japanese font.",
#  'grammar correction: however they are unsuccessful because most of their disarmament were not achieve.',
#  "grammar correction: recently, i'm immerced in running for my weight control.",
#  'grammar correction: but, my weight is more bigger than two week ago.',
#  'grammar correction: i have given up smoking for two week because i want to get my health.',
#  'grammar correction: since i stopped smoking, my running pitch is very well more and more.',
#  'grammar correction: my wife and i give my father white polo - shirts that buy unicro.',
#  'grammar correction: then, we take a lunch thai curry restaurant.',
#  'grammar correction: there is a variety of curry menu green, yellow, red and all.',
#  'grammar correction: i live in okinawa where is very warm and beautiful oceans.',
#  'grammar correction: however, i do not go for swimming, i like spend the time doing nothing',
#  'grammar correction: i have had a time to music activity to appear on rocal radio in okinawa and',
#  'grammar correction: when i and my friend entered in the cafe we were surprised its moods.',
#  'grammar correction: we were very fun.',
#  'grammar correction: today, it will be held music live!',
#  'grammar correction: today\'s events name is " clap hands returns " that was very popular event in the',
#  'grammar correction: we had a lot of memories there...',
#  'grammar correction: but we do not do anything, coz we are not kids but adults.',
#  'grammar correction: however i think it is not enough once a week for me.',
#  "grammar correction: therefore i'd like to go to school of another one.",
#  'grammar correction: i told with my host family about it and they told " it is ok ".',
#  'grammar correction: after that we went to japanese supermarket and go eat dinner at beef barbecue restaurant.',
#  'grammar correction: i was homesick feeling and also in a little bad condition last week.',
#  'grammar correction: i went to san francisco with who got to know with a thing such as facebook yesterday.',
#  "grammar correction: there is near my host family's house and many shop and cafe!",
#  'grammar correction: i used to here better more than before.',
#  'grammar correction: and, i made friends many japanese and little another country perple.',
#  'grammar correction: i want to make friends more another country perple and i learm english.',
#  'grammar correction: i rode cable car first time and went to coit tower.',
#  'grammar correction: and, i went to buy product of hair care and snack.',
#  'grammar correction: finaly, i went to starbucks coffee and drank coffee, ate a cookie and wrote letter for my boyfriend.',
#  'grammar correction: i went to the city with my friends last night because one of my friend left today.',
#  'grammar correction: there is very crawd because all drink is only $ 2!!',
#  'grammar correction: i have much free time recently, so i makes it a custom to watch a movie in the morning.',
#  'grammar correction: i spend afternoon times studying english and accounting.',
#  'grammar correction: i had never watched movies of clint eastwood.',
#  "grammar correction: i'm glad if you would correct this.",
#  'grammar correction: and i have reading it several time for my study english, that it is written by english.',
#  'grammar correction: the little prince lives in small planet there are small two volcanoes and a rose.',
#  'grammar correction: i like peony - root better than peony but people say peony does king of flower',
#  'grammar correction: its good day have a bbq',
#  'grammar correction: and i could chaged spear tire by road server and returen to shop.',
#  'grammar correction: which is the little prince for twice time.',
#  'grammar correction: i was sad feeling.',
#  'grammar correction: i become like baseball game',
#  'grammar correction: all player has each song one of player had a homeback hit.',
#  'grammar correction: you should believe your feeling instead of you are seeing',
#  'grammar correction: i keep try if i have chance to talk to other country peaple.',
#  'grammar correction: one of my freind recommend to me but i little regret.',
#  'grammar correction: he can speak english, then, i was tried ask to “ would you like to have a coffee or tea',
#  'grammar correction: some of neighbors and i prepare for the lunch for elder people who lived with alone as volunteer.',
#  'grammar correction: but i was shock because, many elder people have been liveing with alone.',
#  'grammar correction: in my opinion my engilsh skills went some steps back since i have this teacher.',
#  'grammar correction: you see, i write all in kana, because i did not learned a lot kanji.',
#  'grammar correction: it ticlkes my engineerity!',
#  'grammar correction: i recognized that the summer is finally end and the autumn is falling.',
#  "grammar correction: i've heard that any people do not enjoy songs of crickets besides the japanese.",
#  'grammar correction: do you know cross bike?',
#  'grammar correction: these days cross bikes are growing in popularity amongst japanese.',
#  'grammar correction: it was great to ride roadway!',
#  'grammar correction: it was a three days and 2 nights event.',
#  'grammar correction: it was because there was the world cup match of japan against cameroon!',
#  'grammar correction: it is so funny to talk this, is not it??',
#  'grammar correction: although it is placed in a middle of the city, there are lots of greenery.',
#  'grammar correction: have you ever heard " fourier transfrom " before?',
#  'grammar correction: and after the practice of fourie transform, that of the new function is frequency.',
#  'grammar correction: actually it is been a week that i feel sickness at my stomach.',
#  "grammar correction: i'm planning to pull out them this saturday!",
#  'grammar correction: what i gave to my mom were a bunch of bath powders!',
#  'grammar correction: there were some cash cards, credit cards, my driver licence, and other stuff in my wallet!',
#  'grammar correction: after that, we gon na hold a lab sport event!',
#  'grammar correction: all of the lab members including professors gon na take part in the tournament!',
#  'grammar correction: what i gave to my mom were a bunch of bath powders!!!',
#  'grammar correction: like the moon, things look different by the points you see from.',
#  'grammar correction: what i wanna say is, right thing might be not right thing for others.',
#  "grammar correction: i'm trying to finish this book with in this month.",
#  'grammar correction: i am so glad that i could back to here!!!',
#  'grammar correction: this is why, traditonailly japanese possess such sensibility.',
#  'grammar correction: i am going to write the things which were happened last week, little by little.',
#  'grammar correction: i also talked with her friends, the director of the band and vice president of the luther college.',
#  'grammar correction: and it was for free to admit.',
#  "grammar correction: i'm thinking to mange my daily schedules in english!",
#  "grammar correction: i'm thinking to manage my daily schedules in english.",
#  'grammar correction: 22: 00 go to the friends house to recieve the copies of notes',
#  'grammar correction: last time, we told our experiences and taught them what the yfu exchange program is.',
#  'grammar correction: we also did many other stuffs to extent of 2 day orientation.',
#  'grammar correction: i bettered my own record of toeic!',
#  'grammar correction: at the bigginning of the school year, i had almost no friend in the university.',
#  'grammar correction: i feel like i just content myself with reading english, but i learned nothing.',
#  'grammar correction: it was way much funner than i thought!',
#  "grammar correction: i'm trying to write a jounal at least once in a 3 days!",
#  'grammar correction: what japanese government said and what foreign press said differed in many accounts.',
#  'grammar correction: as the time rolls on, people are losing their hearts to love the nature.',
#  'grammar correction: we went to the same school and had been in a same class for five years.',
#  "grammar correction: i've written a journal about him and his band a while ago.",
#  'grammar correction: i really reflect on myself about this.',
#  'grammar correction: but this was my first time to take part in.',
#  'grammar correction: and i waited them about 30 minutes under the cold wether.',
#  'grammar correction: i forgot about that this was my firtst time and enjoyed speaking english!',
#  'grammar correction: ( i am the guy who is accidentally kissing with 42 old guy in the second picture. )',
#  'grammar correction: around 22: 30, people started leaving if not they were missing the last trains.',
#  'grammar correction: i was having a really good time.',
#  'grammar correction: i think drinking with foreigners is the funniest way to learn english!',
#  "grammar correction: now i'm wring a paper about the currents state and futere prospects of the energy suppry in japan.",
#  "grammar correction: i'm examining the renewable energy and the nuclear power.",
#  'grammar correction: the more i learn, the more obvious that the development of the nuclear power plant is reasonable.',
#  'grammar correction: this song which you might heve not heard of is named " hailie\'s song. "',
#  'grammar correction: please turn off or put your cellphone into silent mode while the show.',
#  'grammar correction: first thing i want to insist is there is no difference between whale and cow.',
#  'grammar correction: my aim of this year is " learn a lot and play a lot " by efficient time management!',
#  'grammar correction: this year, it means, finally i can focus on my research!',
#  'grammar correction: the wether forecast said tomorrow gon na be cold.',
#  "grammar correction: one girl's high schools at seto city held the study event yesterday.",
#  'grammar correction: so we wanted them to have one more another precious memory of japan!',
#  'grammar correction: oh man, if i did not commit, i could buy an another monitor and a graphic board!!!',
#  'grammar correction: and doctor said he has the metastasis spread of cancer of all around his body.',
#  'grammar correction: can you yell to your grandson you see after an interval of a year?',
#  'grammar correction: i could not thought with what i should tell him.',
#  'grammar correction: when i see him and his gaunt face, i could not check the flow of tear.',
#  'grammar correction: first we were given a paper which is written the article but some sentences are blanked.',
#  'grammar correction: i still cannot get what this one means: " i wondered why the baseball kept getting bigger.',
#  'grammar correction: i think leaves of the trees will turn in autumn and it must be really beautiful.',
#  'grammar correction: i would have not feeling this gloom.',
#  'grammar correction: it is the biggest priority for me to make good on my promises!',
#  'grammar correction: at 13: 00 we gon na look around the lab facilities!',
#  'grammar correction: so i do not know how to remark on it.',
#  'grammar correction: they had a free day in nagoya because the flight reserved would departure this afternoon.',
#  'grammar correction: now i am thinking the reply to old lady.....',
#  'grammar correction: and we appreciate their support ongoing rescue, relief and so on',
#  'grammar correction: so we are trying to send the rescue material and the relief and condolence money.',
#  'grammar correction: and there is some staffs and staffs at the really stands up',
#  'grammar correction: which interractive the conputer using own your fingers.',
#  'grammar correction: it is pretty awesome does also simple at home up working',
#  'grammar correction: when you preginent advice you can alligator when at the pop up and customize for advices',
#  'grammar correction: it is also help to find some the making much videoes',
#  'grammar correction: click on the site and check some other videoes you can see other features at the windows seven.',
#  'grammar correction: we will update all the times so check out them all the times',
#  'grammar correction: as soon as my husband watch it, he shouted " who can eat this all!! "',
#  'grammar correction: we eat it by chopsticks.....',
#  'grammar correction: i sometime visited here when i was a student.',
#  'grammar correction: we were talking our present condition each other.',
#  'grammar correction: i was late science of enviroment because i oversleep this morming ( > _ <; )',
#  'grammar correction: beautiful cherry blossom heals japanese when we feel very tired these situation.',
#  'grammar correction: it seems like it is everlastingly incurable.',
#  'grammar correction: the reason why is because such style might influence student to lose interest in studying language.',
#  'grammar correction: now that the new day gets started, keep chasing my dream.',
#  'grammar correction: i began the piano 6years old.',
#  'grammar correction: please tell me if i can say like this!',
#  'grammar correction: this is the best learning way of english.',
#  'grammar correction: today, i had quarrel with my one of friend who i know about 2 years.',
#  'grammar correction: we went to go to swimming together or beach sometimes, so at that time we are good friends.',
#  'grammar correction: but i noticed he sometimes remarks bad thing to my country, and bad things to our people.',
#  'grammar correction: i think we can not recovery our relationship.',
#  'grammar correction: i know diferent country have diferent coustom, thought, many thing,',
#  'grammar correction: but i tried to look better side and keep good friendship.',
#  'grammar correction: and if you have simmiler experience, tell me something about your notion.',
#  'grammar correction: i am so sorry i guess i made many mistake on my writiing and miss spelling...',
#  'grammar correction: today i know this site at korea internet cafe',
#  'grammar correction: so i stayed all day at home',
#  'grammar correction: so i studied english grammer and memorization english word!',
#  "grammar correction: but after sadako's father dead, her situation was getting worse and worse.",
#  'grammar correction: her loyalty is spirit modern japanese lost.',
#  'grammar correction: a professional sample of foods maker makes every of them by their hands.',
#  'grammar correction: he is leaving from japan in this winter.',
#  'grammar correction: it is serious problem for me, i felt that to only study does not make an interesting parson.',
#  'grammar correction: my plan to go to united states to study',
#  'grammar correction: so now, i study english for toefl exam.',
#  'grammar correction: we personal experience make a cheese and icecrem.',
#  'grammar correction: before three years i went to go america.',
#  'grammar correction: i remnant can not speark english.',
#  'grammar correction: i experience most interesting experience for life.',
#  "grammar correction: if i save many many i go to jessi'house.",
#  'grammar correction: it is very enjoyed too.',
#  'grammar correction: i always struggle with the translation especially when it comes to the poetry.',
#  'grammar correction: when i came back here, i searched on google if there is someone who thinks in the same way.',
#  "grammar correction: \ufeffhi, i'm seonah and i live in vancouver for working holiday.",
#  "grammar correction: so i decide that i'll write diary to here for every day.",
#  "grammar correction: i'm happy now because i'm just lasy women and it is 5: 19 am!",
#  'grammar correction: i already move for 2 times even i just arrived in vancouver around 1 month ago!',
#  'grammar correction: i cannot sure that i can work well in vancouver exclude korean resturant.',
#  'grammar correction: we are visiting her hometown in years.',
#  'grammar correction: as i know, they start to learn english much earlier age even from the pre - school or kindergarten.',
#  'grammar correction: i think even we do not realize we act in a group becasue that has been our life style.',
#  'grammar correction: it was so delicious and people who work at restrant were so kind.',
#  'grammar correction: but my salary is cut 15 percent to ease the company financial crisis.',
#  'grammar correction: i paid 16000yen($177 ) for new pass port.',
#  'grammar correction: my company granted me the 2 weeks special vacation because of 20th anniversary on the job.',
#  'grammar correction: my softball game was called off rain.',
#  'grammar correction: we will be first time visit to malaysia.',
#  'grammar correction: i and my wife are four times visit.',
#  'grammar correction: i am appreciate for you to read my poor english.',
#  'grammar correction: my daughter skips two class of swiming club on today.',
#  'grammar correction: and i search a book what i want to read in collection of a library.',
#  'grammar correction: the book is delivered at convenience - store near my house by a library.',
#  'grammar correction: and i go to convenience - store and receive a book.',
#  'grammar correction: \uf0d8 december 2001: i had worked in 8500 tons of floating dock at saigon shipbuilding industry company.',
#  'grammar correction: natives seldom do speak as for ~ " in like this case. "',
#  'grammar correction: rican(s ), there is not exact expression compensatibly, i think.',
#  'grammar correction: i made a conclusion about the relation between the earthquqke and planet location.',
#  'grammar correction: the last year i wondered that as for the " big " earthquake happen at',
#  'grammar correction: how about each word these, are?',
#  'grammar correction: ※i have remembered that i was taught on first year at junior',
#  'grammar correction: exactly may have been what called plural nown.',
#  'grammar correction: please tell me for fixing this global communication gap anyhow.',
#  'grammar correction: it is as though like someone were fallen the backet upside down, in the sky.',
#  'grammar correction: the bicycle shed, which was hit its roof by rain, and it was',
#  'grammar correction: whenever the new month becomes, i come to want to try new things.',
#  'grammar correction: a way to memorize the kind of good foods for health.',
#  "grammar correction: i'm glad that i still can catch up with everything.",
#  'grammar correction: how can you think from the movie?',
#  'grammar correction: the movie tells us we need not only the science and technology but also the trust and faith.',
#  'grammar correction: i first know then listened to the radio.',
#  'grammar correction: way she used to touch softly his face.',
#  'grammar correction: she looks again the old clock.',
#  'grammar correction: she can stand it anymore and turn on the tv and her eyes got fixed on the screen.',
#  'grammar correction: $ “ hey, what is wrong, babe? ” the boy asks softy, he is tired because of work.',
#  'grammar correction: long time has passed since i wrote a last diary before...',
#  'grammar correction: music preference are various depends on people.',
#  'grammar correction: ( each person has an each preference of music )',
#  'grammar correction: basically the 2alts have a lead role and give instructions to the students.',
#  'grammar correction: so i do not usually use english this class, which was a kind of relieving to me.',
#  'grammar correction: i just only said. "w well,, thank you so much.',
#  'grammar correction: i want to be fluent more!!!!',
#  'grammar correction: i think some of you might say like this:',
#  'grammar correction: i even can not speak japanese very well when i am sleepy, though i am a japanese.',
#  'grammar correction: i am wondering the quality of my sleep is not good enough to wake up daytime.',
#  'grammar correction: pls tell me your idea!!!',
#  'grammar correction: you can not see the reminiscence of old fields unless you go far from the central of the city.',
#  'grammar correction: but as least i want to enjoy communication with students when i teach them.',
#  'grammar correction: there i decided to talk what i have in mind more positively.',
#  'grammar correction: well, today i wanna translate below sentences.',
#  'grammar correction: family plays a very important role in the sound growth of juveniles.',
#  'grammar correction: it is been a long time since i wrote my diary last',
#  "grammar correction: recently i've been doing a tutoring job, like at a college prep school and home tutoring.",
#  "grammar correction: by the way, i'm gon na take an english exam called eiken, the 1st grade.",
#  'grammar correction: i am so nervous that i cannot speak englsih well, even i cannot speak japanese well.',
#  'grammar correction: however, i feek so isolated that neither i can open my heart nor relax myself.',
#  'grammar correction: so i have decided to wake up more earlier and take some exercise.',
#  'grammar correction: my friend was kind enough to correct my sentece but i have nt understood some correction.',
#  'grammar correction: we spent almost all dat practicing because it has been a long time to meet together.',
#  'grammar correction: it is been a long time to enter my diary...',
#  'grammar correction: today, the cold deteriorates because i helped the senior till late time yesterday.',
#  'grammar correction: so my condition is broken at noon when i went to work.',
#  'grammar correction: now that i eat some light diner, and i will go to bed to be quiet.',
#  'grammar correction: declining rate of marriage, but it is out of problem to abolish the',
#  'grammar correction: making efforts even if i face plights.',
#  'grammar correction: please correct my essay of english.',
#  'grammar correction: finally, it is another problem that shortage of teachers who can',
#  'grammar correction: cherry blossoms have already passed its best.',
#  'grammar correction: well the rain of cherry blossoms now have fallen and look like carpets of flowers on the ground.',
#  'grammar correction: i am a middle aged japanese home maker who want to improve english.',
#  'grammar correction: so, i cannot make up mind the style of dictionary, digital or paper.',
#  'grammar correction: so, i would like to know about system of underagrduate international students in your school.',
#  'grammar correction: maybe there was neighborhood of our house. said i.',
#  'grammar correction: i am a beginner and a little that i can.',
#  'grammar correction: from that what is now growing youth, depends the future of the country.',
#  'grammar correction: can not limit us, otherwise the entire interest in all things lost.',
#  "grammar correction: today's my mission is to lead variety opinions from members rather than output my opinions.",
#  'grammar correction: i said i cannot do that way for my diet, i do not like running.',
#  'grammar correction: the first thing we done when arrived was going swimming.',
#  'grammar correction: after that, we prepared our luggage to come back home.',
#  'grammar correction: it is bad for me because i have many work that i have to do...',
#  'grammar correction: i engage in the special project in my work now.',
#  'grammar correction: i had the test of english today.',
#  'grammar correction: during summer season, fireworks events have been held throughout japan.',
#  'grammar correction: and i think that this can help me with my english while i also can help others.',
#  'grammar correction: a picture flame, kitchengoods, wine glasses,,,,,',
#  "grammar correction: i'm going to take the massage with one of my frends in the universty age.",
#  "grammar correction: if i'm a rich, i hire a massager, first of all ☆",
#  'grammar correction: there is power outage weekly schedule from electric power company.',
#  'grammar correction: my hobby is jog, but i cannot do it now......',
#  'grammar correction: she is in a hospital from last saturday.',
#  'grammar correction: i like listening music, but now i decided to listen to english only!',
#  'grammar correction: i was lucky that the underwears were 50 % discount.',
#  'grammar correction: today, i went a language school for registing the course with my friend.',
#  'grammar correction: i want to be a good friend to my friends as them.',
#  'grammar correction: it is a movie with a historic event as battle of thermopylae.',
#  "grammar correction: although i expected it is hot, it was't very hot.",
#  'grammar correction: i ended the technological university in speciality - the engineer of polymers chemistry and paints.',
#  'grammar correction: so, i work in 1c company this moment.',
#  'grammar correction: we drunk much alcohol, so we slept as if we would died.',
#  'grammar correction: within one minute or two、tv program: american dance idol will begin!',
#  'grammar correction: japanese constitution allow anyone whose ageis over16 to donate blood of 200cc.',
#  "grammar correction: this bamboo flute would be my grandfather's father's -and i succeeded to it as a remembracnce.",
#  'grammar correction: the reason was that it was believed, if you should speak a word, your wish may not be fulfilled.',
#  'grammar correction: this book introduce slang words and lines that used in a movie " full metal jacket ".',
#  'grammar correction: are there such books like that in other country?',
#  'grammar correction: i usually spend weekends to go shopping or do excacise or just relax.',
#  'grammar correction: i always think that to keep a diary in english is a good way to plactice my english skills.',
#  'grammar correction: it has passed for 1 year since i came the u.',
#  'grammar correction: i do not know it is good or bad.',
#  "grammar correction: i've been to london uk last year for 2 month to learn english.",
#  "grammar correction: oh, it is so late, i've just felt strong sleepy!",
#  'grammar correction: are lots of patients having allergy to pollen in your country?',
#  'grammar correction: according to a weather forecast of today, it is fine day tomorrow.',
#  'grammar correction: especially japanese people are fascinated by falling cherry blossoms.',
#  'grammar correction: as it may be known in only japan, it is a national campaign against increasing of co2 emission.',
#  'grammar correction: but nowadays i have only a problem with taking photos.',
#  'grammar correction: thus each file size of photos is very large, about 15 mb a photo!',
#  'grammar correction: i want to be a person like who have a strong sense of responsibility and always keep her mind.',
#  "grammar correction: but i need not've felt so.",
#  "grammar correction: i've always been generous to show my great respect to the fantastic nature.",
#  'grammar correction: because to buy need of new year party.',
#  'grammar correction: but i cannot speak english, and more hardly study.',
#  'grammar correction: i got up early morning today.',
#  "grammar correction: it is also mother's day, we are going to our parent's home afternoon.",
#  'grammar correction: we rarely go out at night so we are excited very well today.',
#  "grammar correction: it is the costom that we go back our parent's home new year in japan.",
#  'grammar correction: why i stay in nagano even it is colder is because i decided to extend an agreement.',
#  'grammar correction: i will study hard lest i should regret.',
#  'grammar correction: as soon as i go out beauty parlor, it raing and snowy.',
#  'grammar correction: travel around the world always it was my wish.',
#  'grammar correction: i think it is a excellent web site for who want to learn a foreign language.',
#  'grammar correction: i used to have a blog but i am not typing it frequently.',
#  'grammar correction: it is natural that there are crest and tough in our live.',
#  'grammar correction: we are extremely appreciate what they did since we were cold and not used to the weather.',
#  'grammar correction: i wentn to around city for shoping on boxing day.',
#  "grammar correction: i've bought bag some cosmetics some clothes etc..",
#  "grammar correction: i think the other's teleplay chuck also is great.",
#  'grammar correction: my english will become more and more better.',
#  'grammar correction: i think it improve my english level especially my english speak.',
#  'grammar correction: two days is the new year.',
#  'grammar correction: so, in th last days, the most point is vocabulary.',
#  'grammar correction: especially pocket monstar loved by children, young people and junior senior generation.',
#  'grammar correction: united states may requests increase of japanese costs for us military bases.',
#  'grammar correction: us probably think the cost is need for japanese peace between china.',
#  'grammar correction: but japan will request decrease the cost, because the gathering had thought the cost is too higher.',
#  'grammar correction: i suppose japan decide to make new relationship, between us and china.',
#  'grammar correction: asia economics is going to expand next ten years.',
#  "grammar correction: it is caused, chinese ship's captain arrested by japanese police.",
#  'grammar correction: i supposed that this is a defficult problem.',
#  'grammar correction: one of the my dream is to live near beech in okinawa: d',
#  'grammar correction: they spend virtual date in their girl friend, and enjoyed virtual romance.',
#  'grammar correction: they should get real girlfriend, so they will be more happy.',
#  'grammar correction: but she announce that " i\'m a man ", and many people surrprised it.',
#  'grammar correction: so i hope that she will get great efforts in new stage!',
#  'grammar correction: do you know what sports is popular about watching tv in the world?',
#  'grammar correction: cricket is not probably popular in japan.',
#  'grammar correction: i have playing tennis since 12 years old.',
#  'grammar correction: i joined some big project, but we have many many problem to archive it.',
#  'grammar correction: it was 152th game of him, that is 10 days later than last year.',
#  'grammar correction: the great record do not achieved any other him.',
#  "grammar correction: i'm proud of his success as the same japanese.",
#  'grammar correction: but japanese young woman dreaming to marriage the rare men.',
#  "grammar correction: the other hand, the men probably dont't hope to marriage them.",
#  'grammar correction: some japanse women dreaming to marriage the men.',
#  'grammar correction: so first time i just use wii to exercise.',
#  'grammar correction: however, i wanted to experiment this device like a homebrew and dvd',
#  'grammar correction: beacause i slept without blanket on the last night.',
#  'grammar correction: i took medicine at the morning and i almost recover my sinus cold at night.',
#  'grammar correction: so some guys taked ski in the middleo of the city.',
#  "grammar correction: apple's new gizmodo. ipad!!",
#  'grammar correction: it is a little expensive more than i think.',
#  'grammar correction: it looks like not only me, but all aroud the world interested in android phone.',
#  'grammar correction: it is very good except price.',
#  'grammar correction: i hope that korea soccer team keep steam up.',
#  'grammar correction: i hope that korea soccer team keep steam up.',
#  'grammar correction: the half of the 2010 was gone.',
#  'grammar correction: but open the beach is meaning the half of the 2010 was already gone.',
#  'grammar correction: i thought i have to study more hard.',
#  'grammar correction: so maybe i anticipate real movie.',
#  'grammar correction: so i am waitng worldcup eagerly.',
#  'grammar correction: this island is most beautiful i ever seen.',
#  'grammar correction: i walk along the island and met good peoples and talked about many',
#  'grammar correction: i went this island five times but this island is good every time.',
#  'grammar correction: because it can use for exercing.',
#  'grammar correction: recently, weather is too cold so it is hard to exercise outside.',
#  'grammar correction: shopping with woman is really hard thing to man.',
#  'grammar correction: and i knew more about afghanistan.',
#  'grammar correction: i want to see more pieces of work of her.',
#  'grammar correction: recently there are many earthquake around the world.',
#  'grammar correction: and similar movie is knowing.',
#  'grammar correction: anyway after i saw a movie, concerned that tragedy would be occur.',
#  'grammar correction: i really want to buy a ipad but ipad is not selling in korea.',
#  'grammar correction: korea soccer team won japan.',
#  'grammar correction: but we can only chang new cellphone only one day when you received.',
#  "grammar correction: i want to know other country's policy.",
#  'grammar correction: i like not only story but also soundtrack.',
#  "grammar correction: i alreay know acdc but it is the first time to hear their's song.",
#  "grammar correction: a lot of people is anticipate that if iphone4 is released the optimus - q's price will more cheap.",
#  'grammar correction: i felt upset not because the expectable low grade, but for not finishing what i can actually do.',
#  'grammar correction: japan was preparing secretly for war.',
#  'grammar correction: my boyfriend had been a hot temper person, but he improvemented himself for staying by my side.',
#  'grammar correction: when i talk louder and emotional unconsciously, he was quiet and gazed at me with smile.',
#  'grammar correction: i found his change, so i realized that my talking attitude had was too impatient.',
#  'grammar correction: no, i think you are anger when we talked about the wretched farmers, due to you are kindhearted.',
#  'grammar correction: if someone hears nice song, please share to me!!',
#  'grammar correction: this is a beautiful but sorrow song, i very love it!!',
#  'grammar correction: ( because our dream accomplish by myself. )',
#  'grammar correction: ( you had always said that there are a lot of time and you can waiting for me )',
#  'grammar correction: this is a avril\'s lastest song, and her cd " goodbye lullaby " will publishes in 2011/03/08.',
#  'grammar correction: all i want is to mess around and i do not really care about.',
#  'grammar correction: yesterday, there was a match portugal vs north korea.',
#  'grammar correction: i have been to taiwan on a school trip about 1 month ago.',
#  'grammar correction: i waiting for much comment!',
#  "grammar correction: i'm going to write diary about second country that i want to go.",
#  'grammar correction: after that i created account in livejournal and became part of russian community there.',
#  'grammar correction: even more, i started using internet in 1999 and i started it from international part.',
#  'grammar correction: so i believe that this lang-8 space will bring back " international " part back to me.',
#  'grammar correction: for example, for those ones who is studying russian or just interested in russian reality?',
#  "grammar correction: we also saw many salesperson go with wherever we go even we don''t want to buy any.",
#  'grammar correction: the afternnoon is very quiet, i can only hear the voices of beating the keyboard.',
#  'grammar correction: the feeling become impetuous slowly, and i do not know where can i to go.',
#  'grammar correction: the sweetness from chocolate and the smell from mint make me immersion into the another world.',
#  'grammar correction: not only the taste attract me, but the appearance is fascinated.',
#  'grammar correction: i have not met someone love it as me.',
#  'grammar correction: i just finish my first group meeting with profession and seniors.',
#  'grammar correction: and also i have to prepare a ppt to present result.',
#  'grammar correction: sometime i will with my boyfriend to watching moive or walk in the afternoon.',
#  'grammar correction: or together lunch with good friend.',
#  'grammar correction: myabe just watching tv or talk about with my mother or help my dog to bath.',
#  'grammar correction: i feel happy weekend off soon.',
#  'grammar correction: but i just runing ten minute, i feel my leg is very aching.',
#  'grammar correction: because i do not have sport in the ordinery day.',
#  'grammar correction: i am go learning english class in today.',
#  'grammar correction: click girls who wanna know some good tips about fashion!',
#  'grammar correction: japanese truly has their own fashion style!',
#  'grammar correction: i have gone to eat the sushi together with the junior of laboratory.',
#  'grammar correction: only i am in the laboratory today',
#  'grammar correction: it is necessary to maintain it neatly.',
#  "grammar correction: as a recent situation report, it finished finally writing the master's thesis.",
#  'grammar correction: especially, x - ray astronomy and the pulsar are learned.',
#  'grammar correction: i realy hope to success his surgery.',
#  'grammar correction: name salvador he get from his brother, which die previous year.',
#  'grammar correction: when he was 5 years old — his parents said, that he is reincarnation his brother.',
#  'grammar correction: salvador always was a very strange and always tried to attract attention.',
#  'grammar correction: and he continued draw until die his wife and muse gala in 1982.',
#  'grammar correction: after that his works become more and more easy.',
#  'grammar correction: how said salvador « surrealism it is i am ».',
#  'grammar correction: i think this a great chance for me to practice my english speaking and make friends with them.',
#  'grammar correction: i have never known there was so many problems about my writing skill.',
#  'grammar correction: i worried about the date coz..',
#  'grammar correction: my friends are very fine!',
#  'grammar correction: it one of the my dream: )',
#  'grammar correction: i left here a long time.',
#  'grammar correction: since the beginning of the summer vacation, i did not go anywhere yet.',
#  'grammar correction: i was belong to a student council so i have to finish accounting for a school festival.',
#  'grammar correction: after that, i came back to home, i studied only three hour.',
#  'grammar correction: i felt that i have to study more hard.',
#  'grammar correction: why she can speak english!?',
#  'grammar correction: but it is far from here and every time crowded.',
#  'grammar correction: awaited time has come at last.',
#  'grammar correction: we went to near the front and sang together.',
#  'grammar correction: a person from abroad behind us and he was song well.',
#  'grammar correction: i thought i have to study more hard.',
#  'grammar correction: so i will take many pictures then, and i want to put more good pictures.',
#  'grammar correction: i could seen a rainbow appeared when on my way home from a school.',
#  'grammar correction: i bought two nail polish and a tank top.',
#  "grammar correction: i'm so careless mother that i think.",
#  "grammar correction: i think i' ve broken thoese things every once a month...",
#  "grammar correction: when i've been to newzealand, i've met many people andi've had a great experience there.",
#  'grammar correction: i was keeping in touch with them for a few years, and some of them met here in japan again.',
#  'grammar correction: and snow condition was also excellent on sunday.',
#  'grammar correction: also, a ear drum were made by fascia; fortunately my middle ear is normal by nature.',
#  'grammar correction: now i am waiting for getting cured the part in my house.',
#  'grammar correction: day before yesterday, i told my boss that i want to go to working abroad.',
#  'grammar correction: i think that the laws must change for out brighten life.',
#  'grammar correction: that was my worst decision ever to went hospital in a weekend.',
#  'grammar correction: why should not i thought of that!',
#  'grammar correction: even at last i get in sleep, my sleep was not deeply and i was easy to wake up.',
#  'grammar correction: many of them are list in world culture heritage like:',
#  'grammar correction: acturally i went to visit them for several time already.',
#  'grammar correction: she said all the wedding preparation will do by her and her fiance.',
#  'grammar correction: that scause the price increasing of merchandise.',
#  'grammar correction: i am learning english for several years.',
#  'grammar correction: even at last i get in sleep, my sleep was not deeply and i was easy to wake up.',
#  'grammar correction: but he was a little different with before because wearing a grean wig.',
#  'grammar correction: and the most unbelievable thing is he was not look like afraid but excited.',
#  'grammar correction: this is my first time to write diary on this sns.',
#  'grammar correction: well, if you guys were hungry, what confectionery will you eat?',
#  'grammar correction: would you tell me what you like kind of confectionery and eating with your correction?',
#  'grammar correction: i finally have been checking out the tv program"the o.',
#  'grammar correction: no, have to lose weight.',
#  "grammar correction: i've eat too much lately, might be hated from my girl with this x <",
#  'grammar correction: i usually spend a holiday with shopping, have a lunch with my friend, etc.',
#  'grammar correction: is there a case of only you meet with friends and talk?',
#  'grammar correction: i think, if someone are back on their feet from trouble, will need a strong wills.',
#  'grammar correction: so, i conceive to divide thesises list by years.',
#  'grammar correction: when i was as a volunteer during 2009 deaflympics at taipei.',
#  "grammar correction: my parent's friends in usa invited me to go to usa for 1. 5 month.",
#  'grammar correction: i went to many places in usa.',
#  'grammar correction: i stayed in north carolina almost time, but i went to dc, atlanta, baltimore.',
#  'grammar correction: dc has many museums for free.',
#  'grammar correction: it was many flavors that i had never drunk in taiwan.',
#  'grammar correction: michael jordan was graduated from university of nc, i had never known before.',
#  'grammar correction: i want to i can visit usa as soon as possible in the future.',
#  'grammar correction: this is my first step to goal.',
#  'grammar correction: but among these games, stories are great and songs are melodius.',
#  'grammar correction: my purpose to start lang-8 is to meet a lot of game fans and anime fans in abroad.',
#  'grammar correction: in japan, to make dream come true is very difficult, but i cannot give up.',
#  'grammar correction: so, to make friends in foreign country in english is best way to',
#  'grammar correction: i had been playing the guitar in power metal band in japan 3 years ago..',
#  'grammar correction: i have made original song and i see you it.',
#  'grammar correction: i want to brush up my skill by listening metal radio station, so please tell me some.',
#  'grammar correction: my goal is to get high score of toeic and becoming a translater of translating english to japanese.',
#  'grammar correction: i sent a e - mail to my senior to play with me, but he will not have come until when we promised.',
#  'grammar correction: competeing with previous job, the now job is easy and interesting.',
#  'grammar correction: until 8th february, i have no off.',
#  'grammar correction: we, all the businessperson, just behave like them: dog, boy, laser pointer or cameraman.',
#  'grammar correction: different policies makes me difficult to read the us market.',
#  'grammar correction: /the market is getting shrinking.',
#  'grammar correction: i could buy its " 207 series " for $ 28370.',
#  'grammar correction: writing this post, i feel like to listen to an upper music.',
#  "grammar correction: ( i revised this post along to sannask's advice. )",
#  'grammar correction: let us pose " lion " together for health.',
#  'grammar correction: in the midday of this week, i am feeling like skipping my job.',
#  'grammar correction: a week ago, he came with english papers and asked me its translation.',
#  'grammar correction: of course you know, each country has each own law itself and the system.',
#  'grammar correction: please let me know " what do you think is good or bad? "',
#  'grammar correction: watching exciting sports game, i often feel like giving a message or else to the players.',
#  'grammar correction: please help my english.',
#  'grammar correction: hi, tonight i introduce you the site of a chinese character test.',
#  'grammar correction: it is so importananananana lol',
#  'grammar correction: executive director, always do the his own right thing against troubles.',
#  'grammar correction: i am happy to work here and i will enjoy the rest of their stay for 3 days.',
#  'grammar correction: [ jpn][art][video]happy life with chopsticks',
#  'grammar correction: and i saw more than one time!!',
#  'grammar correction: i decided to work there because the foreigners that live in japan, almost work at factory.',
#  'grammar correction: till now it is a bit of fun, little by little i am doing traslation too.',
#  'grammar correction: the toys of train, it is popular in japan, there are people who like to make correction of it ^^',
#  'grammar correction: i want to go to there for out not fot job hehe',
#  'grammar correction: to tell the truth, i am not sure that i will could do it perfectty, but i will try hard!',
#  'grammar correction: i wanna study more to xould help more people!',
#  'grammar correction: there are a baby with just 3 months too, he is so cute!!',
#  'grammar correction: wrong article gets a misunderstand.',
#  'grammar correction: not need something special and very expensive machine or tools.',
#  'grammar correction: 3d printer is too expensive to buy for using personal yet.',
#  'grammar correction: that story is same as anime stand alone complex 1st season.',
#  'grammar correction: watch it if you wanna know japanese sense of value.',
#  "grammar correction: i am recently really obsessed with the news of japan's powerplant problem.",
#  'grammar correction: i found a sentence in a dictionary " he made tokyo on monday. "',
#  'grammar correction: sometimes i feel so, but cause of such loneliness make me communicate with',
#  'grammar correction: that is i speak too fast.',
#  'grammar correction: maybe it caused that i got excited and tried express myself too eager.',
#  'grammar correction: some seemed feeling little confused my english.',
#  'grammar correction: i want to know the name of cafeteria and details of locarion.',
#  'grammar correction: thank you for your advance for your help in this matter.',
#  'grammar correction: becaus i selected to student on a scholarship by kuwait goverment this year.',
#  'grammar correction: this is my first writing about me.',
#  "grammar correction: if my english be better like a native speaker, it is certain i'm lucky guy.",
#  'grammar correction: in first, i try to write my first diary...',
#  'grammar correction: if i had known in a crowd, i might not have gone there.',
#  'grammar correction: i have been sick last week.',
#  'grammar correction: i was not sure what was the name of a disease.',
#  'grammar correction: annual the program',
#  'grammar correction: i could not have eat food after pulled my teeth.',
#  'grammar correction: there was a class of chinese and i had a chinese',
#  'grammar correction: it is so difficult for me to listening this pronounce.',
#  'grammar correction: if i have a time more, i would study russian and thai language.',
#  'grammar correction: so, i want to work chemical plant the future.',
# ...
#  'grammar correction: people enjoy to eat something, to feel art.',
#  'grammar correction: i might be biggum alittle....',
#  'grammar correction: there is similar to english conversation school.',
#  'grammar correction: but, that cafe do not need us the appointment to enter there.',
#  'grammar correction: so, we can go there every time when we wanna talk in english.',
#  'grammar correction: the main bodies of conversation are around me, like seasons, alchole, hobby, gambles, and etc...',
#  'grammar correction: my roommate introduce this website for me.',
#  'grammar correction: yesterday, i have taken part in cet6(college english test-6 ).',
#  "grammar correction: i'm determined to improve english, not only for test.",
#  'grammar correction: i hope it would clear up as soon as possible, do not interrupt my trip.',
#  'grammar correction: liaised the chinese and india corporation and ensured a smooth trade with accurate and fluent',
#  'grammar correction: i even did not past the first interview.',
#  'grammar correction: is it a dream, a dream i was even not brave to admit to myself, has finally come true?',
#  'grammar correction: or is it just an accident result from fascinating scene and a certain time of staying together?',
#  'grammar correction: i am a chinese student of msc accounting & finance at the university of bath.',
#  'grammar correction: i wonder they especially he feel it delicious.',
#  'grammar correction: now i enjoy with my new friends and old friends of ex - university.',
#  'grammar correction: nabe is japanese tradition food and there are many kinds of nabe.',
#  'grammar correction: i found to have written wrong years on very important document.',
#  'grammar correction: i found my back opened, but i went back my home with it opened.',
#  'grammar correction: my classmate will go to a skiing trip next week.',
#  'grammar correction: i do not seem to be able to do in important situation.',
#  'grammar correction: because there is very physical, we practice hard from usually.',
#  'grammar correction: i have one story between man who is my friend and women who is his girlfriend.',
#  'grammar correction: following the day, he told me about it and told he does not know what he should say.',
#  'grammar correction: we have just noticed your mail this month.',
#  'grammar correction: today we were called from our president during our work.',
#  "grammar correction: i'm looking forward to go it, and i wish to spend happy time.",
#  "grammar correction: i'can say lot influnce english stencense, maby i less taken.",
#  'grammar correction: so i must ofen say it even is not corret.',
#  'grammar correction: all menbers always hardly work, but some problem always happened.',
#  'grammar correction: nobody to help me, i cannot give up, we are must hardly futher more and help each ther.',
#  'grammar correction: three days ago we have got to the suzhou, this is the famous city in ancientry china and now.',
#  'grammar correction: she had a tower with 7 floors, i hear this tower build of many many years ago.',
#  'grammar correction: especially, there are many beautiful show girls!',
#  'grammar correction: but new style is not so many only new products.',
#  'grammar correction: ( what am i do on new year.. )',
#  'grammar correction: people does not just happy to bad economy, and for me..',
#  "grammar correction: after a few years later i have to get a job, although i'm young yet but it is stressful.",
#  'grammar correction: about during 1month, i lived without any idea cause i want to separate from reality.',
#  'grammar correction: i have joined pre - intermadiate2 in summer.',
#  'grammar correction: why english is felt like loads for me?',
#  'grammar correction: or watch many dramas and shows?',
#  'grammar correction: when i was elementary school student, at that time rollerskating is so had populared.',
#  'grammar correction: so i could nt ask to help me.',
#  'grammar correction: anyway finally i said i will go home alone and went to home alone nealy creeping.',
#  'grammar correction: i watched one movie to familiar with british english accent.',
#  'grammar correction: as i watched that movie about 4~5times, the ost is quite accustomed to hear.',
#  'grammar correction: i found their songs more and one site where i can download variety songs.',
#  "grammar correction: already as you know, all those things are abba's famous songs.",
#  'grammar correction: of course i had known their a few songs, but had done like very much.',
#  'grammar correction: it was about second grade in elementary school when i thought about my hero at first.',
#  'grammar correction: but i have not my hero.',
#  'grammar correction: so i started to think someone who is worthy to answer that question.',
#  "grammar correction: but it was not real our's and there was lots of unlettered person yet.",
#  'grammar correction: after i determined him of my hero, he is my hero but unreal hero.',
#  'grammar correction: they were not afraid of death, ro rather, some patriots sacrificed themselves for contry.',
#  'grammar correction: i have leared english since april, 2009.',
#  'grammar correction: i write the diary foe the first time. lol',
#  'grammar correction: i cooked lunch box this morning.',
#  'grammar correction: therefore, it was felt that meal at the lunch time was very delicious.',
#  'grammar correction: i have four family.',
#  'grammar correction: my name at so mean " cancer " if you spell with capital letter.',
#  'grammar correction: please check my grammar correctly..',
#  'grammar correction: i like my class so i come in early morning.',
#  'grammar correction: i have four family.',
#  'grammar correction: can you tell me some questions?',
#  'grammar correction: 4, whether you would choose transgene food at supermarket in life?',
#  'grammar correction: my family spend whole day with my parents in law in the at the second day of the lunar new year.',
#  'grammar correction: i had gone to catacombs to worship the ancester at fifth day by tradition.',
#  'grammar correction: i had gone to workplace start to work at seventh day.',
#  'grammar correction: everyone can to find out animal year belong to your own in the following order',
#  'grammar correction: chinese today are tend to contrast animal character with animal year belong to themselves.',
#  "grammar correction: i'm interested in the tour very much!",
#  "grammar correction: they were so cute, but heavy, and paws(tiger's hands ) were so big!",
#  'grammar correction: the philosophy sounds like only quibbling.',
#  'grammar correction: but, its quality of sound is very bad!!',
#  'grammar correction: i play dodge ball with children in rest time.',
#  'grammar correction: but, they were very heavy, so we were tired to carry them and make juice.',
#  'grammar correction: my dog is not loyal very well.',
#  'grammar correction: i could not buy any food or drink till the second station because of no time.',
#  'grammar correction: it is been a while since i last wrote an entry journal here.',
#  'grammar correction: a foreign couple were sharing a piece sitting next us.',
#  'grammar correction: foreign people already started to return their own countries.',
#  'grammar correction: i had work 3hours at japanese sushi restaurants as trial staff yesterday',
#  'grammar correction: i could not get to wage, despite that i worked like crazy in rush hour',
#  'grammar correction: it is my first time of working holiday for me and oversea',
#  'grammar correction: at the first, i did not know how to getting off the bus',
#  "grammar correction: but i do not want to working there in one's heart",
#  'grammar correction: because most of asian restaurants are employ at cheap wages',
#  'grammar correction: store manager told me you can start to $ 10(aud )',
#  "grammar correction: i'm going to working holiday in australia august.",
#  'grammar correction: i do not know that how can i say thinking.',
#  'grammar correction: today, it is windy, weather so cool.',
#  'grammar correction: because i born and live 20 years in central highland, i can sustain hot weather.',
#  'grammar correction: and should i memorize for only the qualification?',
#  'grammar correction: today i write diary in english for the first time in life.',
#  'grammar correction: his occupation is agriculture, so i did various thing about growing vegetables.',
#  'grammar correction: i say to an adult with the artwork first.',
#  'grammar correction: i was not interested in the way of tea before.',
#  'grammar correction: the green tea is good for health.',
#  'grammar correction: there was sometimes the visitor of the foreigner.',
#  'grammar correction: you wipe it and have only to clean it.',
#  'grammar correction: ( the second picture is a picture that traditional game experience. )',
#  'grammar correction: i wish that not gotten more rain',
#  'grammar correction: i came to see a movie idea to write a review',
#  'grammar correction: i want to shop later with my friends',
#  'grammar correction: its needed in my part time job on this summer.',
#  'grammar correction: anyways, im now 17, i think its the time for me to change mature, hahaha!',
#  'grammar correction: i watched pk, i thought it is difficult to win to america.',
#  'grammar correction: more little time, we go to drink and i guess i will be drunker so quickly.',
#  'grammar correction: some peole say that, obesity cause not only diseases but also lose self -confident.',
#  'grammar correction: it is essential to pretect gluttony.',
#  'grammar correction: taking a exercise should encourage to take off fat and for stimulattion blood circulation.',
#  'grammar correction: morever, if they know who succed in diet it will be a good role model for them.',
#  'grammar correction: they will spend tough time to make a goal.',
#  'grammar correction: then, with students asking owner, everybody observe behavior of animal.',
#  'grammar correction: after that, they change a room and discuss result of diagnostic process with an interview.',
#  'grammar correction: in some cases, owner have a big trouble about their pets, we paid much attention.',
#  'grammar correction: today i found my efforts about my experiences would go to just waste.',
#  'grammar correction: i was taught how to use flow cytometer and precaution about experiment.',
#  'grammar correction: today, i typewrote korean language using my pc.',
#  'grammar correction: now, the writing written by me vanished away!',
#  'grammar correction: i want to speak english better, but i do not know why it make.',
#  'grammar correction: but reading is the passive side of using a language and one also be able to active in it.',
#  'grammar correction: however in other ways, for example, raising taxes would end up to force people live less happily.',
#  'grammar correction: noticeable one is " georgia ".',
#  'grammar correction: then what difference with " rubbish " and " garbage "?',
#  'grammar correction: recently, people calls his / her own child very strange name are increasing in my country too. )',
#  'grammar correction: why first names of characters in japanese comics are so strange for you too?',
#  "grammar correction: because i've never been thinking about this topic until that day.",
#  "grammar correction: why japanese fictional character's first names are so strange?",
#  'grammar correction: third, to make reader easy to remember the name.',
#  'grammar correction: thinking for long time, but eventually my stupid answer to that tourist should be true.',
#  'grammar correction: so we sometimes confuce like " how can i call your name like that!?',
#  'grammar correction: he said to me directly nothing about his marriage, so it was surprising for me.',
#  'grammar correction: the loud noise bothers me and hinders to concentrate on my work.',
#  'grammar correction: we discussed with our colaboratory members in netherlands.',
#  'grammar correction: we need not to go to netherlands, and they need not go to japan.',
#  'grammar correction: we have a busy week, and at last it is friday, that is the day before weekend.',
#  'grammar correction: we deserve to refresh or enjoy on the weekend if we have done hard work during the week.',
#  'grammar correction: i read some books in these days during the summer vacation.',
#  'grammar correction: it is fun, even funner than expected.',
#  'grammar correction: relay is very fun and 24 hour relay is more fun than you think.',
#  'grammar correction: its flowers is said to vary its colors by the ph of the soil.',
#  'grammar correction: just at the moment, it starts snowing sentimentally even dramatically.',
#  'grammar correction: i took a day off today, so i have seven - day consecutive holidays.',
#  'grammar correction: each of my family has stuffs of themselves respectively.',
#  'grammar correction: moreover, i have a lot of various things which are new for me every day, even every hour.',
#  'grammar correction: in my dream, i watched a football game of japan versus england national team on tv.',
#  'grammar correction: my busyness is still, or even increased unfortunately.',
#  'grammar correction: we must not apply fertilizer too much to grass especially in the mid summer.',
#  'grammar correction: i am afraid if i could have done it well but i got it done anyway.',
#  'grammar correction: i suppose you that you had better not take like this tough test on friday evening after work.',
#  'grammar correction: thanks to study here in lang-8, i could managed to have discussion in english.',
#  'grammar correction: and all of us left behind.',
#  'grammar correction: i ran in the shade as possible to minimize the exposure to direct sunlight.',
#  'grammar correction: as you know, the open innovation is one of the main stream of the business and r&d collaboration.',
#  'grammar correction: and have been conducting research about the open innovation since this spring.',
#  'grammar correction: we are now learning about the open inovation in europe and us compared with japanese one.',
#  'grammar correction: i will replace to a new refill into the 100yen ballpoint pen.',
#  'grammar correction: i left my office to home at a few minute to the midnight.',
#  'grammar correction: i introduce you how i manage to change my sports outfits into my office clothes.',
#  'grammar correction: it was just midnight when i arrived at home after the long long riding train from the business trip.',
#  'grammar correction: we enjoy seeing and drinking some alcohol.',
#  'grammar correction: sounds like that exciting, does not it?',
#  'grammar correction: she has been working in our laboratory as a temp staff, and she found her permanent job.',
#  'grammar correction: we talk with some collaborators in netherlands while we are still in japan.',
#  'grammar correction: in recently, i wrote bad to whom chews loudly here, so does god punish me with this?',
#  'grammar correction: this photo was taken at the finish point of the route after 20 km walk.',
#  'grammar correction: i was at office until around the midnight some days in a week.',
#  "grammar correction: there was one of my son's high just some days ago.",
#  'grammar correction: someone seems to transfer to another department.',
#  'grammar correction: unhappily i forgot them...',
#  'grammar correction: i wonder if i am tired or for lack of sleep...',
#  'grammar correction: especially i feel sore in lower front of thighs.',
#  'grammar correction: we had heavy rain in japan, especially in kanto area these days.',
#  'grammar correction: it takes much time.',
#  'grammar correction: i am always surprised there are many enthusiastic runners, including us.',
#  'grammar correction: our running buddies will run in 5 teams, 2 for 24h relay and 2 for 6h relay.',
#  'grammar correction: to tell the truth, i did not have the non overwork days of my own since april.',
#  'grammar correction: we find spring has come here certainly.',
#  'grammar correction: i studied as hard as the last time last year.',
#  'grammar correction: today, november 23th is labor thanksgiving day.',
#  'grammar correction: thanks all labors.',
#  'grammar correction: i myself think i am a run freak, may be a run dependence, to some extent.']

# %%
# Tokenize the input and target texts
input_encodings = tokenizer(
    input_texts, padding=True, truncation=True, max_length=128, return_tensors="pt"
).to(device)
target_encodings = tokenizer(
    target_texts, padding=True, truncation=True, max_length=128, return_tensors="pt"
).to(device)

# %%
# Prepare labels with padding
labels = target_encodings["input_ids"]
labels[labels == tokenizer.pad_token_id] = -100

# %%
# Step 4: Create a PyTorch Dataset and DataLoader
class GrammarCorrectionDataset(Dataset):
    def __init__(self, input_encodings, labels):
        self.input_encodings = input_encodings
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return {
            "input_ids": self.input_encodings["input_ids"][idx],
            "attention_mask": self.input_encodings["attention_mask"][idx],
            "labels": self.labels[idx],
        }

dataset = GrammarCorrectionDataset(input_encodings, labels)
train_loader = DataLoader(dataset, batch_size=4, shuffle=True)

# %%
# Step 5: Fine-Tune the Model
optimizer = AdamW(model.parameters(), lr=5e-5)

model.train()
epochs = 3
for epoch in range(epochs):
    epoch_loss = 0
    for batch in train_loader:
        optimizer.zero_grad()
        batch = {k: v.to(device) for k, v in batch.items()}
        outputs = model(**batch)
        loss = outputs.loss
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
    print(f"Epoch {epoch + 1}/{epochs}, Loss: {epoch_loss / len(train_loader):.4f}")
# Out:
# Epoch 1/3, Loss: 0.9998
# Epoch 2/3, Loss: 0.7807
# Epoch 3/3, Loss: 0.6884

# %%
# Step 6: Save the Fine-Tuned Model
model.save_pretrained("t5-grammar-correction")
tokenizer.save_pretrained("t5-grammar-correction")

print("Model fine-tuning completed and saved!")
# Out:
# Model fine-tuning completed and saved!

# %%
# Step 7: Grammar Correction Inference
def correct_grammar(sentence, model, tokenizer):
    input_text = "grammar correction: " + sentence
    input_ids = tokenizer.encode(input_text, return_tensors="pt").to(device)
    outputs = model.generate(input_ids, max_length=128, num_beams=4, early_stopping=True)
    corrected_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return corrected_text

# %%
# Example Usage
model.eval()
test_sentences = [
    "recently, i'm immerced in running for my weight control.",
    "the every female enployees were surrounding him.",
]
for sentence in test_sentences:
    print(f"Original: {sentence}")
    print(f"Corrected: {correct_grammar(sentence, model, tokenizer)}\n")
# Out:
# Original: recently, i'm immerced in running for my weight control.
# Corrected: recently, i'm immersed in running for my weight control.
#
# Original: the every female enployees were surrounding him.
# Corrected: the every female enployee was surrounding him.

# %%
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration

# Check for GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load the Fine-Tuned Model and Tokenizer
model_path = "t5-grammar-correction"  # Directory where the fine-tuned model is saved
tokenizer = T5Tokenizer.from_pretrained(model_path)
model = T5ForConditionalGeneration.from_pretrained(model_path).to(device)

# Function for Grammar Correction
def correct_grammar(sentence, model, tokenizer):
    input_text = "grammar correction: " + sentence
    input_ids = tokenizer.encode(input_text, return_tensors="pt").to(device)
    outputs = model.generate(input_ids, max_length=128, num_beams=4, early_stopping=True)
    corrected_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return corrected_text

# Main Loop for Manual Input
print("Grammar Correction using T5 Model")
print("Type 'exit' to stop the program.\n")

while True:
    sentence = input("Enter a sentence to correct: ").strip()
    if sentence.lower() == "exit":
        print("Exiting the program. Goodbye!")
        break
    corrected_sentence = correct_grammar(sentence, model, tokenizer)
    print(f"Corrected Sentence: {corrected_sentence}\n")
# Out:
# Grammar Correction using T5 Model
# Type 'exit' to stop the program.
# Enter a sentence to correct:  I are surprised in this genration
# Corrected Sentence: I am surprised at this genration.
# Enter a sentence to correct:  He was tried to ran in the harshee weather
# Corrected Sentence: he was tried to run in the harsh weather.
# Enter a sentence to correct:  exit
# Exiting the program. Goodbye!

# %%
pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (4.66.5)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (0.27.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (1.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Downloading xxhash-3.5.0-cp312-cp312-macosx_11_0_arm64.whl (30 kB)
# Installing collected packages: xxhash, multiprocess, datasets
# Successfully installed datasets-3.2.0 multiprocess-0.70.16 xxhash-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: datasets>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from evaluate) (3.2.0)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.12/site-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /opt/anaconda3/lib/python3.12/site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/lib/python3.12/site-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/anaconda3/lib/python3.12/site-packages (from evaluate) (4.66.5)
# Requirement already satisfied: xxhash in /opt/anaconda3/lib/python3.12/site-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /opt/anaconda3/lib/python3.12/site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /opt/anaconda3/lib/python3.12/site-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.6.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from evaluate) (0.27.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from evaluate) (24.1)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from datasets>=2.0.0->evaluate) (3.13.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from datasets>=2.0.0->evaluate) (16.1.0)
# Requirement already satisfied: aiohttp in /opt/anaconda3/lib/python3.12/site-packages (from datasets>=2.0.0->evaluate) (3.10.5)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.12/site-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->evaluate) (2023.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.11.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install rouge_score absl-py
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting absl-py
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: nltk in /opt/anaconda3/lib/python3.12/site-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /opt/anaconda3/lib/python3.12/site-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.12/site-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.12/site-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from nltk->rouge_score) (2024.9.11)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from nltk->rouge_score) (4.66.5)
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=984a62ebbf3cdc023702a3076d3daa8e0c8d9c5cec6b14f7501820b3dbcbbb2c
#   Stored in directory: /Users/usmanali/Library/Caches/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge_score
# Installing collected packages: absl-py, rouge_score
# Successfully installed absl-py-2.1.0 rouge_score-0.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration
import evaluate
import pandas as pd

# Check for GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load Fine-Tuned Model and Tokenizer
model_path = "t5-grammar-correction"  # Replace with your model directory
tokenizer = T5Tokenizer.from_pretrained(model_path)
model = T5ForConditionalGeneration.from_pretrained(model_path).to(device)

# Load Dataset (CSV file with columns: 'input_text', 'corrected_text')
#data_path = "test_dataset.csv"  # Path to your dataset
df = data

# Initialize Metrics
rouge = evaluate.load("rouge")
bleu = evaluate.load("bleu")
accuracy = 0
total_samples = len(df)

# Ensure predictions and references are strings
predictions = []
references = []

for _, row in df.iterrows():
    input_text = "grammar correction: " + row['input']
    expected_output = row['target']

    # Tokenize and generate the model output
    input_ids = tokenizer.encode(input_text, return_tensors="pt").to(device)
    outputs = model.generate(input_ids, max_length=128, num_beams=4, early_stopping=True)
    predicted_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    # Collect predictions and references as strings
    predictions.append(predicted_text.strip())
    references.append(expected_output.strip())  # Ensure this is also a plain string

# Evaluate with ROUGE
rouge_result = rouge.compute(predictions=predictions, references=references)

# Display Results
print("ROUGE Evaluation Results:")
for key, value in rouge_result.items():
    print(f"{key}: {value:.4f}")
# Out:
# ROUGE Evaluation Results:
# rouge1: 0.8427
# rouge2: 0.6689
# rougeL: 0.8285
# rougeLsum: 0.8285
